# %% [markdown]
# <a href="https://colab.research.google.com/github/danon6868/BI-ml-2024/blob/main/lecture_8_pytorch/homework/FC_NN_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Всем привет! Сегодня вы впервые попробуете написать свою собственную нейронную сеть и попробовать ее обучить. Мы будем работать с картинками, но пока что не совсем тем способом, которым лучше всего это делать, но должно получиться неплохо.
#
# Будем работать с [датасетом](https://github.com/rois-codh/kmnist) `Kuzushiji-MNIST` (`KMNIST`). Это рукописные буквы, изображения имеют размер (28, 28, 1) и разделены на 10 классов, по ссылке можно прочитать подробнее.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Сейчас мы будем использовать встроенные данные, но в реальности приходится писать свой класс для датасета (Dataset), у которого реализовывать несколько обязательных методов (напр, `__getitem__`), но это обсудим уже потом.

# %%
import torchvision
from torchvision.datasets import KMNIST


# Превращает картинки в тензоры
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()])

# Загрузим данные (в переменных лежат объекты типа `Dataset`)
# В аргумент `transform` мы передаем необходимые трансформации (ToTensor)
trainset = KMNIST(root="./KMNIST", train=True, download=True, transform=transform)
testset = KMNIST(root="./KMNIST", train=False, download=True, transform=transform)

clear_output()

# %% [markdown]
# Определим даталоадеры, они нужны, чтобы реализовывать стохастический градиентный спуск (то есть мы не хотим считывать в оперативную память все картинки сразу, а делать это батчами).

# %%
from torch.utils.data import DataLoader


# Можно оставить таким
batch_size = 256

trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# Подумайте, как может влиять на скорость обучения параметр `batch_size`, почему вы так считаете?
#
# **Ответ:** Чем больше `batch_size`, тем выше будет скорость обучения, т.к. датасет будет разбит на меньшее число частей и нужно будет совершить меньше итераций для вычисления градиентного спуска. Но слишком большое число батчей может повлиять на качество обучения.

# %% [markdown]
# Посмотрим на какую-нибудь картинку:

# %%
plt.imshow(trainset[0][0].view(28, 28).numpy(), cmap="gray")
plt.axis("off")
plt.title(f"Class is {trainset[0][1]}", fontsize=16);

# %% [markdown]
# ### Задание 1. Смотрим на картинки
#
# **2** балла
#
# Нарисуйте на одном графике изображения всех 10 классов:

# %% [markdown]
# ⣿⣿⣿⣿⣿⣿⠿⢋⣥⣴⣶⣶⣶⣬⣙⠻⠟⣋⣭⣭⣭⣭⡙⠻⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⡿⢋⣴⣿⣿⠿⢟⣛⣛⣛⠿⢷⡹⣿⣿⣿⣿⣿⣿⣆⠹⣿⣿⣿⣿
# ⣿⣿⣿⡿⢁⣾⣿⣿⣴⣿⣿⣿⣿⠿⠿⠷⠥⠱⣶⣶⣶⣶⡶⠮⠤⣌⡙⢿⣿
# ⣿⡿⢛⡁⣾⣿⣿⣿⡿⢟⡫⢕⣪⡭⠥⢭⣭⣉⡂⣉⡒⣤⡭⡉⠩⣥⣰⠂⠹
# ⡟⢠⣿⣱⣿⣿⣿⣏⣛⢲⣾⣿⠃⠄⠐⠈⣿⣿⣿⣿⣿⣿⠄⠁⠃⢸⣿⣿⡧
# ⢠⣿⣿⣿⣿⣿⣿⣿⣿⣇⣊⠙⠳⠤⠤⠾⣟⠛⠍⣹⣛⣛⣢⣀⣠⣛⡯⢉⣰
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡶⠶⢒⣠⣼⣿⣿⣛⠻⠛⢛⣛⠉⣴⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⡿⢛⡛⢿⣿⣿⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡈⢿⣿
# ⣿⣿⣿⣿⣿⣿⣿⠸⣿⡻⢷⣍⣛⠻⠿⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⢇⡘⣿
# ⣿⣿⣿⣿⣿⣿⣿⣷⣝⠻⠶⣬⣍⣛⣛⠓⠶⠶⠶⠤⠬⠭⠤⠶⠶⠞⠛⣡⣿
# ⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣬⣭⣍⣙⣛⣛⣛⠛⠛⠛⠿⠿⠿⠛⣠⣿⣿
# ⣦⣈⠉⢛⠻⠿⠿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠛⣁⣴⣾⣿⣿⣿⣿
# ⣿⣿⣿⣶⣮⣭⣁⣒⣒⣒⠂⠠⠬⠭⠭⠭⢀⣀⣠⣄⡘⠿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡈⢿⣿⣿⣿⣿⣿

# %%
unique_classes = np.unique(trainset.targets.numpy())

fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(10, 5))
axs = axs.flatten()

for i, class_label in enumerate(unique_classes):
    img = trainset.data[trainset.targets == class_label][0]
    axs[i].imshow(img, cmap="gray")
    axs[i].set_title(f"Class {class_label}")
    axs[i].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Задание 2. Строим свой первый MLP
#
# **4** балла
#
# MLP (multilayer perceptron) или нейронная сеть из полносвязных (линейных) слоев, это мы уже знаем.
#
# Опишите структуру сети: 3 полносвязных слоя + функции активации на ваш выбор. **Подумайте** про активацию после последнего слоя!
#
# Сеть на выходе 1 слоя должна иметь 256 признаков, на выходе из 2 128 признаков, на выходе из последнего столько, сколько у вас классов.
#
# https://pytorch.org/docs/stable/nn.html?highlight=activation#non-linear-activations-weighted-sum-nonlinearity

# %%
import torch.nn as nn

class FCNet(nn.Module):
    def __init__(self):
        super().__init__() #  это надо помнить!
        ## YOUR CODE HERE

        self.fc1 = nn.Linear(in_features=28*28, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=10)
        self.activation = nn.ReLU()  # пусть будет ReLU, т.к. вроде он самый гуд по лекции

    def forward(self, x):  # Forward вызывается внутри метода __call__ родительского класса
        ## x -> тензор размерности (BATCH_SIZE, N_CHANNELS, WIDTH, HEIGHT)
        ## надо подумать над тем, что у нас полносвязные слои принимают векторы

        ## YOUR CODE HERE
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        x = self.activation(x)
        logits = self.fc3(x)
        # намек понят, последний слой не активируем

        return logits

# %% [markdown]
# Сколько обучаемых параметров у вашей модели (весов и смещений)?
#
# **Ответ:**

# %% [markdown]
# Весов: (784 * 256) + (256 * 128) + (128 * 10) = 234752
#
# Смещений: 256 + 128 + 10 = 394
#
# Обучаемых параметров: 234752 + 394 = **235146**

# %% [markdown]
# ### Задание 3. Напишите код для обучения модели
#
# **5** баллов
#
# Можно (и нужно) подглядывать в код семинара по пайторчу. Вам нужно создать модель, определить функцию потерь и оптимизатор (начнем с `SGD`). Дальше нужно обучать модель, при помощи тренировочного `Dataloader'a` и считать лосс на тренировочном и тестовом `Dataloader'ах`.

# %% [markdown]
# Напишем функцию для рассчета `accuracy`:

# %%
def get_accuracy(model, dataloader):
    """
    model - обученная нейронная сеть
    dataloader - даталоадер, на котором вы хотите посчитать accuracy
    """
    correct = 0
    total = 0
    with torch.no_grad(): # Тензоры внутри этого блока будут иметь requires_grad=False
        for images, labels in dataloader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total

    return accuracy

# %% [markdown]
# #### Основной цикл обучения
#
# Этот код можно (и зачастую нужно) выносить в отдельную функцию, но пока что можете это не делать, все по желанию)

# %%
# Создадим объект модели
fc_net = FCNet()
# Определим функцию потерь
loss_function = nn.CrossEntropyLoss()
# Создадим оптимизатор для нашей сети
lr = 0.001 # скорость обучения
optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

# %% [markdown]
# Напишите цикл обучения. Для начала хватит 10 эпох. Какое значение `accuracy` на тестовой выборке удалось получить?

# %%
n_epochs = 10
loss_history = []

## YOUR CODE HERE

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader: # Получаем батч тренировочных картинок
        optimizer.zero_grad() # чтобы не было как в лог регрессии, когда мы не обнуляли градиенты
        outputs = fc_net(images) # делаем предсказания
        loss = loss_function(outputs, labels) # считаем лосс
        loss.backward() # считаем градиенты
        optimizer.step() # делаем шаг градиентного спуска

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))

    print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch=1 loss=0.9213
# Epoch=2 loss=0.4533
# Epoch=3 loss=0.3565
# Epoch=4 loss=0.2953
# Epoch=5 loss=0.2525
# Epoch=6 loss=0.2188
# Epoch=7 loss=0.1904
# Epoch=8 loss=0.1682
# Epoch=9 loss=0.1488
# Epoch=10 loss=0.1333

# %%
print(f"Accuracy on train data: {get_accuracy(fc_net, trainloader)}")
print(f"Accuracy on test data: {get_accuracy(fc_net, testloader)}")
# Out:
# Accuracy on train data: 0.9688333333333333
# Accuracy on test data: 0.8721

# %% [markdown]
# ### Задание 4. Изучение влияния нормализации
#
# **3** балла
#
# Вы могли заметить, что мы забыли провести нормализацию наших данных, а для нейронных сетей это может быть очень критично.
#
# Нормализуйте данные.
#
# * Подсчитайте среднее значение и стандартное отклонение интенсивности пикселей для всех тренировочных данных
# * Нормализуйте данные с использованием этих параметров (используйте трансформацию `Normalize`)
#
#
# Оцените влияние нормировки данных.

# %%
mean = sum(pict[0].mean() for pict, _ in trainset) / len(trainset)
std = sum(pict[0].std() for pict, _ in trainset) / len(trainset)

print(mean, std)

transform_with_norm = torchvision.transforms.Compose([
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize(mean, std)
            ])

trainset.transform = transform_with_norm
testset.transform = transform_with_norm
# Out:
# tensor(0.1918) tensor(0.3385)

# %%
fc_net = FCNet()
loss_function = nn.CrossEntropyLoss()
lr = 0.001
optimizer = torch.optim.Adam(fc_net.parameters(), lr=3e-4)

# %%
n_epochs = 10
loss_history = []

## YOUR CODE HERE
for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader: # Получаем батч тренировочных картинок
        optimizer.zero_grad() # чтобы не было как в лог регрессии, когда мы не обнуляли градиенты
        outputs = fc_net(images) # делаем предсказания
        loss = loss_function(outputs, labels) # считаем лосс
        loss.backward() # считаем градиенты
        optimizer.step() # делаем шаг градиентного спуска

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))

    print(f"Epoch={epoch+1} loss={loss_history[epoch]:.4f}")
# Out:
# Epoch=1 loss=0.6940
# Epoch=2 loss=0.3063
# Epoch=3 loss=0.2233
# Epoch=4 loss=0.1742
# Epoch=5 loss=0.1387
# Epoch=6 loss=0.1122
# Epoch=7 loss=0.0917
# Epoch=8 loss=0.0755
# Epoch=9 loss=0.0627
# Epoch=10 loss=0.0508

# %%
print(f"Accuracy on train data: {get_accuracy(fc_net, trainloader)}")
print(f"Accuracy on test data: {get_accuracy(fc_net, testloader)}")
# Out:
# Accuracy on train data: 0.9916333333333334
# Accuracy on test data: 0.8937

# %% [markdown]
# Как изменилась `accuracy` после нормализации?

# %% [markdown]
# Значение `accuracy` немного увеличилось.

# %% [markdown]
# ### Задание 5. Изучение влияния функции активации
#
# **3** балла
#
# Исследуйте влияние функций активации на скорость обучения и точность предсказаний модели.
#
# Используйте три функции:
#
# * [Sigmoid](https://pytorch.org/docs/stable/nn.functional.html#sigmoid)
# * [GELU](https://pytorch.org/docs/stable/nn.functional.html#gelu)
# * [Tanh](https://pytorch.org/docs/stable/generated/torch.nn.Tanh.html#torch.nn.Tanh)

# %%
## YOUR CODE HERE
class FCNet_func_activation(nn.Module):
    def __init__(self, activation):
        super().__init__()
        self.fc1 = nn.Linear(in_features=28*28, out_features=256)
        self.fc2 = nn.Linear(in_features=256, out_features=128)
        self.fc3 = nn.Linear(in_features=128, out_features=10)
        self.activation = activation

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        x = self.activation(x)
        logits = self.fc3(x)

        return logits

# %%
n_epochs = 10

activation_functions = [nn.Sigmoid(), nn.GELU(), nn.Tanh()]
models = [FCNet_func_activation(activation) for activation in activation_functions]
loss_function = nn.CrossEntropyLoss()

for i, model in enumerate(models):
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
    loss_history = []
    accuracy_history = []
    print(f"Model: {model.activation.__class__.__name__}")

    for epoch in range(n_epochs):
        epoch_loss = 0
        for images, labels in trainloader:
            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        loss_history.append(epoch_loss/len(trainloader))
        accuracy = get_accuracy(model, testloader)
        accuracy_history.append(accuracy)

        print(f"Epoch={epoch+1}, loss={loss_history[epoch]:.4f}, accuracy={accuracy:.4f}")
# Out:
# Model: Sigmoid
# Epoch=1, loss=1.5438, accuracy=0.6302
# Epoch=2, loss=0.7497, accuracy=0.6864
# Epoch=3, loss=0.5434, accuracy=0.7281
# Epoch=4, loss=0.4432, accuracy=0.7566
# Epoch=5, loss=0.3752, accuracy=0.7872
# Epoch=6, loss=0.3226, accuracy=0.8021
# Epoch=7, loss=0.2797, accuracy=0.8205
# Epoch=8, loss=0.2451, accuracy=0.8319
# Epoch=9, loss=0.2154, accuracy=0.8429
# Epoch=10, loss=0.1899, accuracy=0.8544
# Model: GELU
# Epoch=1, loss=0.6527, accuracy=0.7866
# Epoch=2, loss=0.2850, accuracy=0.8341
# Epoch=3, loss=0.2079, accuracy=0.8640
# Epoch=4, loss=0.1586, accuracy=0.8645
# Epoch=5, loss=0.1235, accuracy=0.8801
# Epoch=6, loss=0.0974, accuracy=0.8902
# Epoch=7, loss=0.0788, accuracy=0.8956
# Epoch=8, loss=0.0631, accuracy=0.9027
# Epoch=9, loss=0.0498, accuracy=0.9031
# Epoch=10, loss=0.0387, accuracy=0.9035
# Model: Tanh
# Epoch=1, loss=0.7775, accuracy=0.7345
# Epoch=2, loss=0.3820, accuracy=0.8029
# Epoch=3, loss=0.2602, accuracy=0.8489
# ...

# %% [markdown]
# С использованием какой функции активации удалось досчить наибольшей `accuracy`?

# %% [markdown]
# Наш победитель, хоть и с небольшим отрывом, **GELU**!

# %% [markdown]
# ### Задание 6. Другие оптимизаторы
#
# **4** балла
#
# Исследуйте влияние оптимизаторов на скорость обучения и точность предсказаний модели.
#
# Попробуйте следующие:
#
# * [Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html#torch.optim.Adam)
# * [RMSprop](https://pytorch.org/docs/stable/generated/torch.optim.RMSprop.html#torch.optim.RMSprop)
# * [Adagrad](https://pytorch.org/docs/stable/generated/torch.optim.Adagrad.html#torch.optim.Adagrad)
#
# Вам нужно снова обучить 3 модели и сравнить их перформанс (функцию активации используйте ту, которая показала себя лучше всего).

# %%
n_epochs = 10

model = FCNet_func_activation(nn.GELU())
optimizers = [torch.optim.Adam, torch.optim.RMSprop, torch.optim.Adagrad]
loss_function = nn.CrossEntropyLoss()

for optimizer_class in optimizers:
    model = FCNet_func_activation(nn.GELU())
    optimizer = optimizer_class(model.parameters(), lr=3e-4)
    loss_history = []
    accuracy_history = []
    print(f"Optimizer: {optimizer.__class__.__name__}")

    for epoch in range(n_epochs):
        epoch_loss = 0
        for images, labels in trainloader:
            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        loss_history.append(epoch_loss/len(trainloader))
        accuracy = get_accuracy(model, testloader)
        accuracy_history.append(accuracy)

        print(f"Epoch={epoch+1}, loss={loss_history[epoch]:.4f}, accuracy={accuracy:.4f}")
# Out:
# Optimizer: Adam
# Epoch=1, loss=0.6586, accuracy=0.7847
# Epoch=2, loss=0.2772, accuracy=0.8379
# Epoch=3, loss=0.1981, accuracy=0.8593
# Epoch=4, loss=0.1529, accuracy=0.8784
# Epoch=5, loss=0.1199, accuracy=0.8819
# Epoch=6, loss=0.0967, accuracy=0.8937
# Epoch=7, loss=0.0770, accuracy=0.8940
# Epoch=8, loss=0.0615, accuracy=0.9003
# Epoch=9, loss=0.0487, accuracy=0.8967
# Epoch=10, loss=0.0387, accuracy=0.9060
# Optimizer: RMSprop
# Epoch=1, loss=0.4351, accuracy=0.8105
# Epoch=2, loss=0.2382, accuracy=0.8421
# Epoch=3, loss=0.1755, accuracy=0.8692
# Epoch=4, loss=0.1348, accuracy=0.8812
# Epoch=5, loss=0.1070, accuracy=0.8955
# Epoch=6, loss=0.0849, accuracy=0.8932
# Epoch=7, loss=0.0677, accuracy=0.8983
# Epoch=8, loss=0.0535, accuracy=0.8991
# Epoch=9, loss=0.0411, accuracy=0.9028
# Epoch=10, loss=0.0325, accuracy=0.9044
# Optimizer: Adagrad
# Epoch=1, loss=1.3119, accuracy=0.5889
# Epoch=2, loss=0.7925, accuracy=0.6435
# Epoch=3, loss=0.6750, accuracy=0.6684
# ...

# %% [markdown]
# Лучше всего показал себя **Adam**.

# %% [markdown]
# ### Задание 7. Реализация ReLU
#
# **4** балла
#
# Самостоятельно реализуйте функцию активации ReLU.
# Замените в уже обученной модели функцию активации на вашу. Убедитесь что ничего не изменилась.

# %%
class CustomReLU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        # YOUR CODE HERE
        # если элемент x < 0, то 0, если >= 0, то x
        x = torch.max(torch.tensor(0.0), x)
        return x

# %% [markdown]
# Заново обучите модель и проверьте правильность реализации `CustomReLU`.

# %%
# CustomReLU

n_epochs = 10

model = FCNet_func_activation(CustomReLU())
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
loss_function = nn.CrossEntropyLoss()

loss_history = []
accuracy_history = []

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))
    accuracy = get_accuracy(model, testloader)
    accuracy_history.append(accuracy)

    print(f"Epoch={epoch+1}, loss={loss_history[epoch]:.4f}, accuracy={accuracy:.4f}")
# Out:
# Epoch=1, loss=0.6788, accuracy=0.7824
# Epoch=2, loss=0.2992, accuracy=0.8286
# Epoch=3, loss=0.2222, accuracy=0.8460
# Epoch=4, loss=0.1718, accuracy=0.8639
# Epoch=5, loss=0.1373, accuracy=0.8790
# Epoch=6, loss=0.1110, accuracy=0.8832
# Epoch=7, loss=0.0919, accuracy=0.8902
# Epoch=8, loss=0.0761, accuracy=0.8925
# Epoch=9, loss=0.0606, accuracy=0.8901
# Epoch=10, loss=0.0502, accuracy=0.8995

# %%
# nn.ReLU

n_epochs = 10

model = FCNet_func_activation(nn.ReLU())
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)
loss_function = nn.CrossEntropyLoss()

loss_history = []
accuracy_history = []

for epoch in range(n_epochs):
    epoch_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    loss_history.append(epoch_loss/len(trainloader))
    accuracy = get_accuracy(model, testloader)
    accuracy_history.append(accuracy)

    print(f"Epoch={epoch+1}, loss={loss_history[epoch]:.4f}, accuracy={accuracy:.4f}")
# Out:
# Epoch=1, loss=0.6904, accuracy=0.7747
# Epoch=2, loss=0.3024, accuracy=0.8219
# Epoch=3, loss=0.2223, accuracy=0.8523
# Epoch=4, loss=0.1716, accuracy=0.8732
# Epoch=5, loss=0.1379, accuracy=0.8772
# Epoch=6, loss=0.1105, accuracy=0.8840
# Epoch=7, loss=0.0910, accuracy=0.8895
# Epoch=8, loss=0.0734, accuracy=0.8920
# Epoch=9, loss=0.0608, accuracy=0.8976
# Epoch=10, loss=0.0486, accuracy=0.8990

# %% [markdown]
# Цифры разные, но общий тренд как будто бы прослеживается.

# %% [markdown]
# ### Задание 8. Генерация картинок
#
# **3** балла
#
# Придумайте 3 предложения и сгенерируйте при помощи них 3 картинки, используя телеграм бота [ruDALLE](https://t.me/sber_rudalle_xl_bot). Прикрепите сюда ваши картины.

# %% [markdown]
# Пришлось использовать GigaChat, т.к. ruDALLE не работал :(

# %% [markdown]
# ![cat](../data_folder/processed_data/cat.jpg)

# %% [markdown]
# ![knight](../data_folder/processed_data/knight.jpg)

# %% [markdown]
# ![stars](../data_folder/processed_data/stars.jpg)
